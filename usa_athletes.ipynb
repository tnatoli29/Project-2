# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data set athletes.csv is a data set of all athletes from the Rio de Janiero 2016 Olympics
athletes_file = "Resources/athletes.csv"
athletes_2016 = pd.read_csv(athletes_file)
athletes_2016
# Out:
#               id                name nationality     sex       dob  height  \
# 0      736041664      A Jesus Garcia         ESP    male  10/17/69    1.72
# 1      532037425          A Lam Shin         KOR  female   9/23/86    1.68
# 2      435962603         Aaron Brown         CAN    male   5/27/92    1.98
# 3      521041435          Aaron Cook         MDA    male    1/2/91    1.83
# 4       33922579          Aaron Gate         NZL    male  11/26/90    1.81
# ...          ...                 ...         ...     ...       ...     ...
# 11533  265605954  Zurian Hechavarria         CUB  female   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE  female  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    male   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    male    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    male    1/6/92    1.85
#
#        weight          sport  gold  silver  bronze
# ...

# %%
# Add Year column into the athletes dataset to show '2016'
# Add City column to show where the Olympic city
athletes_2016['year'] = 2016
athletes_2016['city'] = 'Rio de Janeiro'

athletes_2016
# Out:
#               id                name nationality     sex       dob  height  \
# 0      736041664      A Jesus Garcia         ESP    male  10/17/69    1.72
# 1      532037425          A Lam Shin         KOR  female   9/23/86    1.68
# 2      435962603         Aaron Brown         CAN    male   5/27/92    1.98
# 3      521041435          Aaron Cook         MDA    male    1/2/91    1.83
# 4       33922579          Aaron Gate         NZL    male  11/26/90    1.81
# ...          ...                 ...         ...     ...       ...     ...
# 11533  265605954  Zurian Hechavarria         CUB  female   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE  female  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    male   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    male    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    male    1/6/92    1.85
#
# ...

# %%
# Select columns from the data set athletes.csv 
all_athletes_2016 = athletes_2016[['city', 'year', 'name','nationality', 'sex', 'gold', 'silver', 'bronze']]
all_athletes_2016
# Out:
#                  city  year                name nationality     sex  gold  \
# 0      Rio de Janeiro  2016      A Jesus Garcia         ESP    male     0
# 1      Rio de Janeiro  2016          A Lam Shin         KOR  female     0
# 2      Rio de Janeiro  2016         Aaron Brown         CAN    male     0
# 3      Rio de Janeiro  2016          Aaron Cook         MDA    male     0
# 4      Rio de Janeiro  2016          Aaron Gate         NZL    male     0
# ...               ...   ...                 ...         ...     ...   ...
# 11533  Rio de Janeiro  2016  Zurian Hechavarria         CUB  female     0
# 11534  Rio de Janeiro  2016      Zuzana Hejnova         CZE  female     0
# 11535  Rio de Janeiro  2016             di Xiao         CHN    male     0
# 11536  Rio de Janeiro  2016   le Quoc Toan Tran         VIE    male     0
# 11537  Rio de Janeiro  2016      le Roux Hamman         RSA    male     0
#
#        silver  bronze
# 0           0       0
# 1           0       0
# ...

# %%
# Filter only USA athletes from the 2016 dataset
usa_athletes_2016 = all_athletes_2016[all_athletes_2016.nationality == "USA"]
usa_athletes_2016
# Out:
#                  city  year                name nationality     sex  gold  \
# 6      Rio de Janeiro  2016       Aaron Russell         USA    male     0
# 13     Rio de Janeiro  2016    Abbey D'Agostino         USA  female     0
# 14     Rio de Janeiro  2016      Abbey Weitzeil         USA  female     1
# 64     Rio de Janeiro  2016    Abigail Johnston         USA  female     0
# 104    Rio de Janeiro  2016  Adeline Maria Gray         USA  female     0
# ...               ...   ...                 ...         ...     ...   ...
# 11242  Rio de Janeiro  2016          Yijun Feng         USA    male     0
# 11339  Rio de Janeiro  2016              Yue Wu         USA  female     0
# 11436  Rio de Janeiro  2016        Zach Garrett         USA    male     0
# 11437  Rio de Janeiro  2016         Zach Ziemek         USA    male     0
# 11439  Rio de Janeiro  2016           Zack Test         USA    male     0
#
#        silver  bronze
# 6           0       1
# 13          0       0
# ...

# %%
# Final USA Athletes for 2016 dataframe
final_usa_athletes_2016 = usa_athletes_2016[['city', 'year', 'name','nationality', 'sex']]
final_usa_athletes_2016
# Out:
#                  city  year                name nationality     sex
# 6      Rio de Janeiro  2016       Aaron Russell         USA    male
# 13     Rio de Janeiro  2016    Abbey D'Agostino         USA  female
# 14     Rio de Janeiro  2016      Abbey Weitzeil         USA  female
# 64     Rio de Janeiro  2016    Abigail Johnston         USA  female
# 104    Rio de Janeiro  2016  Adeline Maria Gray         USA  female
# ...               ...   ...                 ...         ...     ...
# 11242  Rio de Janeiro  2016          Yijun Feng         USA    male
# 11339  Rio de Janeiro  2016              Yue Wu         USA  female
# 11436  Rio de Janeiro  2016        Zach Garrett         USA    male
# 11437  Rio de Janeiro  2016         Zach Ziemek         USA    male
# 11439  Rio de Janeiro  2016           Zack Test         USA    male
#
# [567 rows x 5 columns]

# %%
# BREAK FOR NEXT DATASET - Summer Olympics for 1976 to 2008

# %%
# Summer Olympic dataset from years 1976 to 2008
summer_file = "Resources/Summer-Olympic-medals-1976-to-2008.csv"
summer_athletes = pd.read_csv(summer_file)
summer_athletes
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
# Select columns from the data set Summer 1976 to 2008.csv 
summer_athletes = summer_athletes[['City', 'Year', 'Athlete','Gender', 'Country_Code', 'Medal']]
summer_athletes
# Out:
#            City    Year                   Athlete Gender Country_Code   Medal
# 0      Montreal  1976.0           KÖHLER, Christa  Women          GDR  Silver
# 1      Montreal  1976.0       KOSENKOV, Aleksandr    Men          URS  Bronze
# 2      Montreal  1976.0      BOGGS, Philip George    Men          USA    Gold
# 3      Montreal  1976.0  CAGNOTTO, Giorgio Franco    Men          ITA  Silver
# 4      Montreal  1976.0    WILSON, Deborah Keplar  Women          USA  Bronze
# ...         ...     ...                       ...    ...          ...     ...
# 15428   Beijing  2008.0        GUENOT, Christophe    Men          FRA  Bronze
# 15429   Beijing  2008.0       KVIRKELIA, Manuchar    Men          GEO    Gold
# 15430   Beijing  2008.0          RAHIMOV, Vitaliy    Men          AZE  Silver
# 15431   Beijing  2008.0            GUENOT, Steeve    Men          FRA    Gold
# 15432   Beijing  2008.0             LOPEZ, Mijain    Men          CUB    Gold
#
# [15433 rows x 6 columns]

# %%
# Filter only USA athletes Summer 1976 to 2008 dataset
usa_summer = summer_athletes[summer_athletes['Country_Code'] == "USA"]
usa_summer
# Out:
#            City    Year                    Athlete Gender Country_Code   Medal
# 2      Montreal  1976.0       BOGGS, Philip George    Men          USA    Gold
# 4      Montreal  1976.0     WILSON, Deborah Keplar  Women          USA  Bronze
# 5      Montreal  1976.0          LOUGANIS, Gregory    Men          USA  Silver
# 7      Montreal  1976.0  POTTER-MCINGVALE, Cynthia  Women          USA  Bronze
# 11     Montreal  1976.0     CHANDLER, Jennifer Kay  Women          USA    Gold
# ...         ...     ...                        ...    ...          ...     ...
# 15314   Beijing  2008.0              SALMON, Riley    Men          USA    Gold
# 15316   Beijing  2008.0            NNAMANI, Ogonna  Women          USA  Silver
# 15380   Beijing  2008.0              CEJUDO, Henry    Men          USA    Gold
# 15398   Beijing  2008.0              MILLER, Randi  Women          USA  Bronze
# 15420   Beijing  2008.0              WHEELER, Adam    Men          USA  Bronze
#
# [1992 rows x 6 columns]

# %%
# Using .rename(columns={}) in order to rename columns
summer_usa_only = usa_summer.rename(columns={"City":"city", "Year":"year", "Gender":"sex", 
                                       "Country_Code":"nationality", "Medal":"medal"})
summer_usa_only.head()
# Out:
#         city    year                    Athlete    sex nationality   medal
# 2   Montreal  1976.0       BOGGS, Philip George    Men         USA    Gold
# 4   Montreal  1976.0     WILSON, Deborah Keplar  Women         USA  Bronze
# 5   Montreal  1976.0          LOUGANIS, Gregory    Men         USA  Silver
# 7   Montreal  1976.0  POTTER-MCINGVALE, Cynthia  Women         USA  Bronze
# 11  Montreal  1976.0     CHANDLER, Jennifer Kay  Women         USA    Gold

# %%
#Change variables values  
summer_usa_only['sex'] = summer_usa_only['sex'].replace(["Men"],'male')
summer_usa_only['sex'] = summer_usa_only['sex'].replace(["Women"],'female')
summer_usa_only
# Out:
#            city    year                    Athlete     sex nationality   medal
# 2      Montreal  1976.0       BOGGS, Philip George    male         USA    Gold
# 4      Montreal  1976.0     WILSON, Deborah Keplar  female         USA  Bronze
# 5      Montreal  1976.0          LOUGANIS, Gregory    male         USA  Silver
# 7      Montreal  1976.0  POTTER-MCINGVALE, Cynthia  female         USA  Bronze
# 11     Montreal  1976.0     CHANDLER, Jennifer Kay  female         USA    Gold
# ...         ...     ...                        ...     ...         ...     ...
# 15314   Beijing  2008.0              SALMON, Riley    male         USA    Gold
# 15316   Beijing  2008.0            NNAMANI, Ogonna  female         USA  Silver
# 15380   Beijing  2008.0              CEJUDO, Henry    male         USA    Gold
# 15398   Beijing  2008.0              MILLER, Randi  female         USA  Bronze
# 15420   Beijing  2008.0              WHEELER, Adam    male         USA  Bronze
#
# [1992 rows x 6 columns]

# %%
#Clean data a bit more
new = summer_usa_only["Athlete"].str.split(",", n=1, expand=True)
summer_usa_only["Last_name"] = new[0]
summer_usa_only["First_name"] = new[1]
summer_usa_only.drop(columns = ["Athlete"], inplace = True)
summer_usa_only["Last_name"] = summer_usa_only["Last_name"].str.capitalize()
summer_usa_only
# Out:
#            city    year     sex nationality   medal         Last_name  \
# 2      Montreal  1976.0    male         USA    Gold             Boggs
# 4      Montreal  1976.0  female         USA  Bronze            Wilson
# 5      Montreal  1976.0    male         USA  Silver          Louganis
# 7      Montreal  1976.0  female         USA  Bronze  Potter-mcingvale
# 11     Montreal  1976.0  female         USA    Gold          Chandler
# ...         ...     ...     ...         ...     ...               ...
# 15314   Beijing  2008.0    male         USA    Gold            Salmon
# 15316   Beijing  2008.0  female         USA  Silver           Nnamani
# 15380   Beijing  2008.0    male         USA    Gold            Cejudo
# 15398   Beijing  2008.0  female         USA  Bronze            Miller
# 15420   Beijing  2008.0    male         USA  Bronze           Wheeler
#
#             First_name
# 2        Philip George
# 4       Deborah Keplar
# 5              Gregory
# 7              Cynthia
# ...

# %%
#Grab first names and last names and combine them together again 
summer_usa_only["name"] = summer_usa_only["First_name"] +" " + summer_usa_only["Last_name"]
del summer_usa_only['Last_name']
del summer_usa_only['First_name']

summer_usa_only
# Out:
#            city    year     sex nationality   medal                       name
# 2      Montreal  1976.0    male         USA    Gold        Philip George Boggs
# 4      Montreal  1976.0  female         USA  Bronze      Deborah Keplar Wilson
# 5      Montreal  1976.0    male         USA  Silver           Gregory Louganis
# 7      Montreal  1976.0  female         USA  Bronze   Cynthia Potter-mcingvale
# 11     Montreal  1976.0  female         USA    Gold      Jennifer Kay Chandler
# ...         ...     ...     ...         ...     ...                        ...
# 15314   Beijing  2008.0    male         USA    Gold               Riley Salmon
# 15316   Beijing  2008.0  female         USA  Silver             Ogonna Nnamani
# 15380   Beijing  2008.0    male         USA    Gold               Henry Cejudo
# 15398   Beijing  2008.0  female         USA  Bronze               Randi Miller
# 15420   Beijing  2008.0    male         USA  Bronze               Adam Wheeler
#
# [1992 rows x 6 columns]

# %%
# Final USA Athletes from Summer 1976 to 2008
final_usa_summer = summer_usa_only[['city', 'year', 'name','nationality', 'sex']]
final_usa_summer
# Out:
#            city    year                       name nationality     sex
# 2      Montreal  1976.0        Philip George Boggs         USA    male
# 4      Montreal  1976.0      Deborah Keplar Wilson         USA  female
# 5      Montreal  1976.0           Gregory Louganis         USA    male
# 7      Montreal  1976.0   Cynthia Potter-mcingvale         USA  female
# 11     Montreal  1976.0      Jennifer Kay Chandler         USA  female
# ...         ...     ...                        ...         ...     ...
# 15314   Beijing  2008.0               Riley Salmon         USA    male
# 15316   Beijing  2008.0             Ogonna Nnamani         USA  female
# 15380   Beijing  2008.0               Henry Cejudo         USA    male
# 15398   Beijing  2008.0               Randi Miller         USA  female
# 15420   Beijing  2008.0               Adam Wheeler         USA    male
#
# [1992 rows x 5 columns]

# %%
# BREAK FOR NEXT - MERGE 2 FILES INTO ONE

# %%
# Merge files together into 1
#merge = pd.concat([final_usa_athletes_2016, final_usa_summer], axis = 0, join; str = "outer")
frames= [final_usa_athletes_2016, final_usa_summer]
usa = pd.concat(frames)
usa.reset_index(inplace=True, drop=True)
usa = usa.astype({'year': 'int'})
usa
# Out:
#                 city  year                name nationality     sex
# 0     Rio de Janeiro  2016       Aaron Russell         USA    male
# 1     Rio de Janeiro  2016    Abbey D'Agostino         USA  female
# 2     Rio de Janeiro  2016      Abbey Weitzeil         USA  female
# 3     Rio de Janeiro  2016    Abigail Johnston         USA  female
# 4     Rio de Janeiro  2016  Adeline Maria Gray         USA  female
# ...              ...   ...                 ...         ...     ...
# 2554         Beijing  2008        Riley Salmon         USA    male
# 2555         Beijing  2008      Ogonna Nnamani         USA  female
# 2556         Beijing  2008        Henry Cejudo         USA    male
# 2557         Beijing  2008        Randi Miller         USA  female
# 2558         Beijing  2008        Adam Wheeler         USA    male
#
# [2559 rows x 5 columns]

# %%
usa['sex'].value_counts()
# Out:
# male      1345
# female    1214
# Name: sex, dtype: int64

# %%
# Split geneder athletes
female = usa[usa.sex == "female"]
male = usa[usa.sex == 'male']

# %%
male_count_by_year = male['year'].value_counts()
female_count_by_year = female['year'].value_counts()

# %%
reset_male = male_count_by_year.reset_index()
reset_male.columns = ['year', 'male']
reset_male
# Out:
#    year  male
# 0  2016   264
# 1  1984   202
# 2  2008   153
# 3  1996   131
# 4  1988   131
# 5  1992   123
# 6  2000   119
# 7  2004   117
# 8  1976   105

# %%
reset_female = female_count_by_year.reset_index()
reset_female.columns = ['year', 'female']
reset_female
# Out:
#    year  female
# 0  2016     303
# 1  2008     162
# 2  2004     147
# 3  1984     131
# 4  2000     129
# 5  1996     129
# 6  1992     101
# 7  1988      62
# 8  1976      50

# %%
# Merge the two male and female count by year files for plotting

merge_gender_files = pd.merge(reset_male, reset_female, on="year")
gender_by_year = merge_gender_files
gender_by_year
# Out:
#    year  male  female
# 0  2016   264     303
# 1  1984   202     131
# 2  2008   153     162
# 3  1996   131     129
# 4  1988   131      62
# 5  1992   123     101
# 6  2000   119     129
# 7  2004   117     147
# 8  1976   105      50

# %%
gender_by_year["total"] = gender_by_year.male + gender_by_year.female
gender_by_year
# Out:
#    year  male  female  total
# 0  2016   264     303    567
# 1  1984   202     131    333
# 2  2008   153     162    315
# 3  1996   131     129    260
# 4  1988   131      62    193
# 5  1992   123     101    224
# 6  2000   119     129    248
# 7  2004   117     147    264
# 8  1976   105      50    155

# %%
# Sort by Year in ascending order
gender_by_year.sort_values('year', axis=0, ascending=True, inplace=True, na_position='first')
gender_by_year
# Out:
#    year  male  female  total
# 8  1976   105      50    155
# 1  1984   202     131    333
# 4  1988   131      62    193
# 5  1992   123     101    224
# 3  1996   131     129    260
# 6  2000   119     129    248
# 7  2004   117     147    264
# 2  2008   153     162    315
# 0  2016   264     303    567

# %%
# Save gender_by_year as a csv file for html plotting
#gender_by_year.to_csv("Resources/totalUSAthletes.csv", index=False)

# %%
# Create lists for plotting
year = gender_by_year['year'].tolist()
total = gender_by_year['total'].tolist()
male = gender_by_year['male'].tolist()
female = gender_by_year['female'].tolist()

# %%
# Plot the charts and apply some styling
# Plot based on Summer Olympic files, all athletes

xaxis = year
tick_locations = []
for x in xaxis:
    tick_locations.append(x)

male, = plt.plot(year, male, marker="o", color="blue", label="Male Athletes")
female, = plt.plot(year, female, marker="o", color="red", label="Female Athletes")

plt.title("Olympic USA Athletes from 1976 to 2016")
plt.xlabel("Olympic Year")
plt.ylabel("Total Number of USA Athletes")
plt.xticks(tick_locations, year)
plt.legend(handles=[male, female], loc="best")

# %%
# Plot shows that starting in Year 2000, male athletes decreased, while female athletes increased
# Note this plot shows Total USA athletes, regardless of medal standing.
# Datasets excludes Year 1980 ad 2012
# Total number of USA Athletes 2259, male = 1345 and female = 1214
